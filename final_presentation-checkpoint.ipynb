# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from IPython import display

# %%
display.Image("./DatA_Team_logo.jpg", width=400)

# %%
# link do folderu z GITA:
# %cd "C:\Users\natal\Desktop\Bootcamp InfoShare Academy\Prace domowe i projekty\projekt Python od 26.02 do 2.04\github repo\"
# Out:
# C:\Users\natal\Desktop\Bootcamp InfoShare Academy\Prace domowe i projekty\projekt Python od 26.02 do 2.04\github repo

# %% [markdown]
# # Uber Eats - What about fries?
#
# Team members:
# - Agnieszka Kołomyjec
# - Barbara Wierzba-Sowińska
# - Krzysztof Łukjanowicz
# - Marcin Sarnowski
# - Natalia Skrzypczak
#
# ### Project Description
#
# #### abcdefghijklmnoprstuwxyz
#
# ### Contents

# %%
restaurants = pd.read_csv('plik.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6064\491563802.py in <module>
# ----> 1 restaurants = pd.read_csv('plik.csv')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'plik.csv'

# %%
cheap = restaurants[restaurants['price_range']=='$']
moderate = restaurants[restaurants['price_range']=='$$']
expensive = restaurants[(restaurants['price_range']=='$$$') + (restaurants['price_range']=='$$$$')]
cheapsy = cheap.groupby('state', as_index=False)['price_range'].count()
#zmiana nazwy na unikatową
cheapsy.rename(columns = {'price_range': 'cheap #'}, inplace=True)

moderasy = moderate.groupby('state', as_index=False)['price_range'].count()
#zmiana nazwy na unikatową
moderasy.rename(columns = {'price_range': 'moderate #'}, inplace=True)

expensy = expensive.groupby('state', as_index=False)['price_range'].count()
#zmiana nazwy na unikatową
expensy.rename(columns = {'price_range': 'expensive #'}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21772\3757429592.py in <module>
# ----> 1 cheap = restaurants[restaurants['price_range']=='$']
#       2 moderate = restaurants[restaurants['price_range']=='$$']
#       3 expensive = restaurants[(restaurants['price_range']=='$$$') + (restaurants['price_range']=='$$$$')]
#       4 cheapsy = cheap.groupby('state', as_index=False)['price_range'].count()
#       5 #zmiana nazwy na unikatową
#
# NameError: name 'restaurants' is not defined

# %%
#nie ma mozliwosci łączenia wielu dataframeów na raz, więc robię to stopniowo
chm = cheapsy.merge(moderasy, how='outer', on ='state')
all = chm.merge(expensy, how='outer', on ='state')

#usuniecie wartosci NaN
all = all.fillna(0)
#nowa kolumna total
all['total'] = all['cheap #'] + all['moderate #'] + all['expensive #']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29572\2092598337.py in <module>
#       1 #nie ma mozliwosci łączenia wielu dataframeów na raz, więc robię to stopniowo
# ----> 2 chm = cheapsy.merge(moderasy, how='outer', on ='state')
#       3 all = chm.merge(expensy, how='outer', on ='state')
#       4
#       5 #usuniecie wartosci NaN
#
# NameError: name 'cheapsy' is not defined

# %%
all['cheap #'] = all['cheap #'] / all['total'] * 100
all.rename(columns = {'cheap #': 'cheap %'}, inplace=True)
all['moderate #'] = all['moderate #'] / all['total'] * 100
all.rename(columns = {'moderate #': 'moderate %'}, inplace=True)
all['expensive #'] = all['expensive #'] / all['total'] * 100
all.rename(columns = {'expensive #': 'expensive %'}, inplace=True)
#zaokrąglenie do dwóch miejsc po przecinku
all = all.round(2)
all
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29572\657136442.py in <module>
# ----> 1 all['cheap #'] = all['cheap #'] / all['total'] * 100
#       2 all.rename(columns = {'cheap #': 'cheap %'}, inplace=True)
#       3 all['moderate #'] = all['moderate #'] / all['total'] * 100
#       4 all.rename(columns = {'moderate #': 'moderate %'}, inplace=True)
#       5 all['expensive #'] = all['expensive #'] / all['total'] * 100
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
all1 = all.drop(2)
all1 = all1.drop(5)
all1 = all1.drop(6)
all1 = all1.drop(9)
all1 = all1.reset_index(drop=True)
all1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29572\2517886069.py in <module>
# ----> 1 all1 = all.drop(2)
#       2 all1 = all1.drop(5)
#       3 all1 = all1.drop(6)
#       4 all1 = all1.drop(9)
#       5 all1 = all1.reset_index(drop=True)
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'drop'

# %%
df = restaurants.value_counts('price_range').rename_axis('price_range').to_frame('total')
#df.loc[df['price_range']=='$$$$', 'price_range']=='$$$$$'
df['sum'] = df['total'].sum()
df['sum'] = df['total'] / df['sum'] * 100
df = df.rename(columns={'sum': '%'})
df = df.round(2)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29572\1408633418.py in <module>
# ----> 1 df = restaurants.value_counts('price_range').rename_axis('price_range').to_frame('total')
#       2 #df.loc[df['price_range']=='$$$$', 'price_range']=='$$$$$'
#       3 df['sum'] = df['total'].sum()
#       4 df['sum'] = df['total'] / df['sum'] * 100
#       5 df = df.rename(columns={'sum': '%'})
#
# NameError: name 'restaurants' is not defined

# %%
alltoplot = all1.drop("total", axis='columns')
alltoplot.plot(x="state", kind = 'bar', stacked=True, mark_right=True);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29572\1849327891.py in <module>
# ----> 1 alltoplot = all1.drop("total", axis='columns')
#       2 alltoplot.plot(x="state", kind = 'bar', stacked=True, mark_right=True);
#
# NameError: name 'all1' is not defined

# %%
veg = restaurants[restaurants['category'].notna()]
vege = veg[veg['category'].str.contains('Veg')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29572\1783440224.py in <module>
# ----> 1 veg = restaurants[restaurants['category'].notna()]
#       2 vege = veg[veg['category'].str.contains('Veg')]
#
# NameError: name 'restaurants' is not defined

# %% [markdown]
# Suma restauracji, w których są dania z kategorii "vege" w poszczególnych stanach

# %%
vegsum = pd.pivot_table(vege, index='state', values='id', aggfunc=len)
vegsum = vegsum.rename(columns={'id': 'Total restaurants with veg'})
vegsum.reset_index(inplace=True)
vegsum
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29572\2887081832.py in <module>
# ----> 1 vegsum = pd.pivot_table(vege, index='state', values='id', aggfunc=len)
#       2 vegsum = vegsum.rename(columns={'id': 'Total restaurants with veg'})
#       3 vegsum.reset_index(inplace=True)
#       4 vegsum
#
# NameError: name 'vege' is not defined

# %% [markdown]
# Ilość restauracji w poszczególnych stanach (punkt odniesienia)

# %%
totalres = pd.pivot_table(restaurants, index='state', values='id', aggfunc=len)
totalres = totalres.rename(columns={'id': 'Total restaurants'})
totalres
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29572\74666445.py in <module>
# ----> 1 totalres = pd.pivot_table(restaurants, index='state', values='id', aggfunc=len)
#       2 totalres = totalres.rename(columns={'id': 'Total restaurants'})
#       3 totalres
#
# NameError: name 'restaurants' is not defined

# %%
sumresveg = totalres.merge(vegsum, how='outer', on = 'state')
sumresveg = sumresveg.fillna(0)
sumresveg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29572\142236408.py in <module>
# ----> 1 sumresveg = totalres.merge(vegsum, how='outer', on = 'state')
#       2 sumresveg = sumresveg.fillna(0)
#       3 sumresveg
#
# NameError: name 'totalres' is not defined

# %% [markdown]
# Procentowa ilość restauracji wege w poszczególnych stanach

# %%
sumresveg['veg restaurants %'] = sumresveg['Total restaurants with veg'] / sumresveg['Total restaurants'] * 100
sumresveg = sumresveg.round(2)
#sumresveg.reset_index(inplace=True)
sumresveg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29572\3599139244.py in <module>
# ----> 1 sumresveg['veg restaurants %'] = sumresveg['Total restaurants with veg'] / sumresveg['Total restaurants'] * 100
#       2 sumresveg = sumresveg.round(2)
#       3 #sumresveg.reset_index(inplace=True)
#       4 sumresveg
#
# NameError: name 'sumresveg' is not defined

# %%
vegsum.plot(kind='bar', x='state', y='Total restaurants with veg')
plt.show()

# %%
vegpr = vege.value_counts('price_range').rename_axis('price_range').to_frame('total')
vegpr = vegpr.reset_index()
vegpr['sum'] = vegpr['total'].sum()
vegpr['sum'] = vegpr['total'] / vegpr['sum']*100
vegpr = vegpr.round(2)
vegpr

# %%
alltoplot = vegpr.drop("total", axis='columns')
alltoplot.plot(x="state", kind = 'bar', stacked=True, mark_right=True);
